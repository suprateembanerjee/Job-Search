# %%
import weaviate
import weaviate.classes as wvc
import ollama
import json
import pickle
import ollama
from collections import Counter
import pandas as pd

# %%
client = weaviate.connect_to_local()
# Out:
# /var/folders/v8/l597fdmn691ctljk27sgct540000gn/T/ipykernel_4437/2610504379.py:1: ResourceWarning: unclosed <socket.socket fd=75, family=30, type=1, proto=6, laddr=('::1', 52337, 0, 0), raddr=('::1', 8080, 0, 0)>
#   client = weaviate.connect_to_local()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# ## Users

# %%
with open ('../data/abouts', 'rb') as file:
    summaries = pickle.load(file)

len(summaries)
# Out:
# 27

# %%
if client.collections.exists('Jobseekers'):
    print('Dropping pre-exisiting collection')
    client.collections.delete('Jobseekers')
    
jobseeker_collection = client.collections.create(name='Jobseekers',
                                                 vectorizer_config=wvc.config.Configure.Vectorizer.text2vec_ollama(api_endpoint='http://host.docker.internal:11434', model='llama3'),
                                                 generative_config=wvc.config.Configure.Generative.ollama(api_endpoint='http://host.docker.internal:11434', model='llama3'))

# %%
json_outputs = []
generation_counts = 0

for summary in summaries:

    prompt_template = f'Given the following summary of a jobseeker: "{summary}" answer the following questions: 1. Enlist the main skills of the jobseeker. \
        2. Is the jobseeker interested in working in a specific location? If yes, mention location. If no, just say "Flexible"\
        3. Is the jobseeker looking for a "Full-Time" role, an "Internship" role, or "Contract" role? If any of these, mention the type name. Else, say "Flexible".\
        4. What are the role titles that the jobseeker is interested in? Be curt, do not explain role.\
        5. Does the jobseeker have experience or interest in specific industries? If so, list the industries, if not, say "Flexible".\
        6. Does the jobseeker have a strong preference for "Remote" work? If so, say "Remote", else say "Flexible". Do not explain, only list.\
        7. Write a 100 word paragraph on the kind of team this person would excel at.\
        Structure answers into a json that can be read using Python json.loads() using the keys "skills", "location", "role_type", "interested_roles", "industries", "remote" and "team_fit" respectively. Do not include any other explanations or sentences in the output. Do not explain how to use it.'

    json_output = None

    while not json_output:

        generation_counts += 1

        output = ollama.generate(model = "llama3",
                                prompt = prompt_template)
        
        for x in output['response'].split('```'):
            try:
                json_output = json.loads(x)
                break
            except:
                pass
    
    json_output['summary'] = summary
    json_outputs.append(json_output)

print(f'It took {generation_counts} LLM calls to extract {len(summaries)} profiles.')
# Out:
# It took 28 LLM calls to extract 27 profiles.
# [{'skills': ['Python',
#    'Machine Learning',
#    'Natural Language Processing',
#    'SQL',
#    'Tableau',
#    'Database Systems',
#    'Data Analytics'],
#   'location': '',
#   'role_type': 'Full-Time',
#   'interested_roles': ['Data Analyst'],
#   'industries': ['Healthcare', 'Customer Segmentation Marketing'],
#   'team_fit': 'I would excel at a team that has a great culture and significant impact to business, with diverse members who appreciate data-driven insights.',
#   'summary': 'Currently seeking Full time Data Analyst roles starting January 2024. Expertise domain knowledge in healthcare and customer segmentation marketing. Python, Machine Learning, Natural Language Processing, SQL, Tableau, Database Systems, Data Analytics. I enjoy programming, working with ML models, and visualizing patterns to get the most value out of data. I graduated with a Bachelor’s in Computer Engineering from University of Mumbai in 2018. As for my future, I aspire to one day work as a Data Scientist with a diverse team that has a great culture and significant impact to business. In my free time, I love to watch space documentaries and cook'},
#  {'skills': ['Cybersecurity', 'Computer languages', 'Platforms', 'Tools'],
#   'location': 'Flexible',
#   'role_type': 'Full-Time',
#   'interested_roles': ['Cybersecurity positions'],
#   'industries': ['National Security'],
#   'team_fit': 'This individual would excel at a team that values strong cybersecurity measures, has a focus on national security and infrastructure protection, and is willing to adapt to new technologies and tools.',
#   'summary': 'I am a MS in Cybersecurity student at Northeastern University who is interested in the cybersecurity of infrastructure and its intersection with cyber-warfare and national security. I am a highly motivated worker who has experience working with a wide range of computer languages, platforms, and tools. I am currently participating in the CyberCorps®: Scholarship for Service program, run by the U.S. Office of Personnel Management, and have committed to working to strengthen the cybersecurity of the US government following my graduation.'},
#  {'skills': ['Python',
#    'C++',
#    'Java',
#    'R',
#    'SQL',
#    'Keras',
#    'PyTorch',
#    'Tensorflow',
#    'Flask',
#    'FastAPI',
#    'AWS',
#    'Azure',
#    'Docker',
#    'NATS',
#    'Git',
#    'Jira'],
#   'location': 'Flexible',
#   'role_type': 'Flexible',
#   'interested_roles': ['Machine Learning Engineer'],
#   'industries': ['Healthcare', 'EdTech', 'Supply Chain'],
#   'team_fit': 'I would excel at a team that values innovation, collaboration, and open communication. A team that is passionate about leveraging AI to make a positive impact in society and is willing to take calculated risks to drive progress.',
#   'summary': 'As a Machine Learning Engineer at Chegg, I apply my passion and expertise in Generative AI, Natural Language Processing, and Deep Learning to develop state-of-the-art AI applications that empower students and educators. I have built deep learning models for question answering, topic prediction, and author extraction, leveraging LLMs, CNNs, and traditional ML models. I am currently working on CheggMate, a revolutionary AI-powered study assistant that powers student learning experiences and helps them master any subject. I have a Master of Science in Computer Science, specializing in Artificial Intelligence, from Northeastern University, where I gained a solid foundation in Deep Learning, Machine Learning, Computer Vision, and Natural Language Processing. I also have 2.5 years of experience in Research and Applied AI in Healthcare, EdTech, and supply chain, working with fast-paced startups and prominent Big Tech corporations. I have strong skills in Python, C++, Java, R, SQL, Keras, PyTorch, Tensorflow, Flask, FastAPI, AWS, Azure, Docker, NATS, Git, Jira, and more. I am an avid learner, conscious of the latest trends in AI and technology, and I enjoy giving tech talks and sharing my insights with the community.'},
#  {'skills': ['Software engineering',
#    'Data science',
#    'Machine learning',
#    'Distributed computing',
#    'Data storage'],
#   'location': 'Flexible',
#   'role_type': 'Full-Time',
#   'interested_roles': ['Software Engineer', 'Senior Software Developer'],
#   'industries': ['Finance', 'Hedge Funds'],
#   'team_fit': 'A team that excels at solving complex technical problems, utilizing machine learning and distributed computing to drive business outcomes.',
#   'summary': "With over six years of experience as a software engineer and a master's degree in data science, I have developed a strong foundation in both technical and analytical skills. I am currently working as a software engineer III at JPMorgan Chase & Co., where I apply my knowledge of machine learning, distributed computing, and data storage to design and implement solutions for the financial sector. Previously, I worked as a senior software developer at The D.E. Shaw Group, a hedge fund known for its quantitative and technology-driven approach. There, I was part of the Quant Data team that handled large volumes of financial data from various sources and platforms. I also interned as a software development engineer at Amazon, where I contributed to the development of a web service that optimized the delivery of digital content. In addition, I have completed several certifications and courses in data science, machine learning, and statistics, as well as a teaching assistant and research assistant role at Northeastern University. I am passionate about learning new technologies and exploring new domains, and I am always eager to take on new challenges and opportunities."},
#  {'skills': ['Software Engineer',
#    'Data Science',
#    'Java',
#    'Python',
#    'PHP',
#    'C++',
#    'JavaScript',
#    'TypeScript',
#    'R',
#    'HTML/CSS',
#    'MySQL',
#    'OracleSQL',
#    'MongoDB',
#    'SQLite',
#    'AWS RDS',
#    'DynamoDB',
#    'Apache Cassandra',
#    'SpringBoot',
#    'React.js',
#    'Node.js',
#    'jQuery',
#    'Hibernate',
#    'Flask',
#    'GraphQL',
#    'Sklearn',
#    'Keras',
#    'Git',
#    'JUnit4',
#    'REST API',
#    'Postman',
#    'Docker',
#    'Kubernetes',
#    'Apache Flink',
#    'Kafka',
#    'Rockset',
#    'AWS S3'],
#   'location': 'Flexible',
#   'role_type': 'Software Engineering and Data Science roles starting immediately. Redhat Certified System Administrator (RHCSA).',
#   'interested_roles': ['Software Engineering', 'Data Science'],
#   'industries': [],
#   'team_fit': 'This person would excel at a team that values collaboration, creative problem-solving, and innovative thinking. They thrive in environments where they can learn from others, share their knowledge, and contribute to meaningful projects.',
#   'summary': "Creative and results-oriented software engineer with 2+ years of experience working with tech companies. Experienced with all stages of the development cycle for dynamic web and ML projects and agile development principles. I like to work on databases, backend and frontend technologies and frameworks, DevOps, implementing and designing product lifecycles and data pipelines. In the realm of deep learning and machine learning, I've worked on natural language processing, computer vision, and unsupervised machine learning, applying these techniques to solve real-world problems. My hands-on experience with tools and technologies such as Docker, Kubernetes, Apache Flink, Kafka, and various AWS services has equipped me to build scalable and efficient systems. Currently looking for Software Engineering and Data Science roles starting immediately. Redhat Certified System Administrator (RHCSA). Languages: Java, Python, PHP, C++, JavaScript, TypeScript, R, HTML/CSS. Databases: MySQL, OracleSQL, MongoDB, SQLite, AWS RDS, DynamoDB, Apache Cassandra. Frameworks: SpringBoot, React.js, Node.js, jQuery, Hibernate, Flask, GraphQL, Sklearn, Keras, Git, Junit4. Tools and Technologies: REST API, Postman, Docker, Kubernetes, Apache Flink, Kafka, Rockset, AWS S3."},
#  {'skills': ['Data Science',
#    'Business Administration',
#    'Social Innovation',
#    'Entrepreneurship'],
#   'location': 'Flexible',
#   'role_type': 'Internship',
#   'interested_roles': ['Tech Intern', 'Finance Intern'],
#   'industries': ['Tech', 'Finance'],
#   'team_fit': 'This individual would excel in a team that values innovation, collaboration, and creativity. Their strong analytical skills and business acumen would make them a valuable asset in a fast-paced and dynamic environment.',
#   'summary': 'I am a graduating senior at Northeastern studying Data Science & Business Administration, with a concentration in social innovation and entrepreneurship. Currently searching for Summer 2024 internships in Tech and Finance before returning to Northeastern as a graduate student to complete a Masters in Data Science as part of the PlusOne program.'},
#  {'skills': ['machine learning',
#    'deep neural networks',
#    'machine learning algorithms',
#    'programming'],
#   'location': 'Flexible',
#   'role_type': 'Flexible',
#   'interested_roles': ['Researcher', 'Engineer', 'Scientist'],
#   'industries': ['Biotechnology',
#    'Computer Vision',
#    'Artificial Intelligence'],
#   'team_fit': 'This person would excel in a team that values innovative problem-solving, collaboration, and open communication. They are well-suited for an environment that encourages experimentation, creativity, and critical thinking.',
#   'summary': "I am a machine learning researcher at New England Biolabs, where I apply my skills in deep neural networks, machine learning algorithms, and programming to develop and deploy solutions for biological problems. I am also a Master's student in Electrical and Computer Engineering at Northeastern University, with a focus on Computer Vision and Deep Learning. Current Research: Active Learning; Explainable and Interpretable AI"},
#  {'skills': ['Machine Learning',
#    'Python',
#    'R',
#    'Scala',
#    'SQL',
#    'C',
#    'C++',
#    'MATLAB',
#    'SciKit-Learn',
#    'NumPy',
#    'Pandas',
#    'SciPy',
#    'Matplotlib',
#    'Seaborn',
#    'TensorFlow',
#    'Keras',
#    'OpenCV',
#    'Spacy',
#    'Polyglot'],
#   'location': 'Flexible',
#   'role_type': 'Flexible',
#   'interested_roles': ['Data Scientist',
#    'Machine Learning Engineer',
#    'Researcher'],
#   'industries': ['Flexible'],
#   'team_fit': 'The jobseeker would excel in a team that values innovation, collaboration, and persistence. They thrive in environments where they can apply their analytical skills to solve complex problems.',
#   'summary': "A graduate student with 2 years of work experience as a Data Scientist. Started this journey in the field of Machine Learning, during my internship where I built a Robokeeper. I'm passionate, detail-oriented and persistent. I wanted to build my career in the field of Machine Learning because it allows an individual to explore different domains. Technical Skills : Programming Languages: Python, R, Scala, SQL, C, C++, MATLAB. Libraries: SciKit-Learn, NumPy, Pandas, SciPy, Matplotlib, Seaborn, TensorFlow, Keras, OpenCV, Spacy, Polyglot. Tools: Amazon EMR, Apache Spark, Apache Hadoop, MongoDB, Jupyter Notebook, R studio, Tableau, PowerBI, JIRA, Git"},
#  {'skills': ['Machine Learning',
#    'ML Operations',
#    'Keras',
#    'Tensorflow (core, JS, Lite)',
#    'Scikit-Learn',
#    'Computer Vision',
#    'Web Development',
#    'Django',
#    'Flask',
#    'CI/CD',
#    'Python/C/C++/Java',
#    'Cloud Tech (AWS, Azure, GCP)'],
#   'location': 'Flexible',
#   'role_type': 'Full-time',
#   'interested_roles': ['Software Engineering',
#    'Data Science',
#    'ML/DL',
#    'ML Ops'],
#   'industries': [],
#   'team_fit': 'This person would excel at a team that values fast-paced work-environments, tight deadlines, and rapid prototyping. They have a keen eye for product and user experience/requirements, making them a strong fit for teams focused on building new experiences for consumers.',
#   'summary': "I have 3 years of experience in building Machine Learning/Deep Learning applications (web/mobile/edge) and designing pipelines for end-to-end ML deployments (ML Ops). Currently I'm pursuing my Masters Degree at Northeastern University (Boston, US), on track to graduate in May 2024 with a major in Computer Science. I have a keen eye for the product and user experience/requirements when designing a product. I have worked in fast-paced work-environments with tight deadlines and I learned that I pick-up new technologies quickly which helps me iterate through prototypes faster. I can add great value to your ML Team and help build new experiences for your consumers. I'm seeking Full-time Software Engineering roles (in Data Science/ML/DL/ML Ops) starting August 2024. Feel free to message me :) Competencies: Machine Learning, ML Operations, Keras, Tensorflow (core, JS, Lite), Scikit-Learn, Computer Vision, Web Development, Django, Flask, CI/CD, Python/C/C++/Java, Cloud Tech (AWS, Azure, GCP) Accomplishments: Winner at HackHarvard Hackathon '22 for 'Best use of Google Cloud'."},
#  {'skills': ['C++', 'Python', 'Java', 'Angular', 'Django', 'Flask'],
#   'location': 'Flexible',
#   'role_type': 'Flexible',
#   'interested_roles': ['Software Engineer'],
#   'industries': ['Climate Change', 'Business'],
#   'team_fit': 'This person would excel at a team that is passionate about building products that bring positive impact to the world, and values collaboration, innovation, and creativity.',
#   'summary': 'I am a graduate student pursuing Computer Science at Northeastern University, Boston. I am self-motivated, hard-working, passionate about, and excited to learn new technologies. Prior to joining, Northeastern, I worked as Software Engineer at Teradata R&D, building some cool Advanced Analytics packages for our customers. My top skills include C++, Python, Java, Angular, Django, Flask. I’m passionate about building products that bring a positive impact to the world, from a business application to one that fights climate change.'},
#  {'skills': ['Data Science', 'Data Analytics', 'Machine Learning'],
#   'location': 'Flexible',
#   'role_type': 'Full-Time',
#   'interested_roles': ['Data Scientist',
#    'Business Intelligence Analyst',
#    'Data Analyst'],
#   'industries': ['Healthcare', 'Finance', 'Technology'],
#   'team_fit': 'This person would excel in a collaborative team that values innovation, creativity and experimentation. They thrive in an environment where they can share ideas, learn from others and take calculated risks to drive business outcomes.',
#   'summary': 'I am an MS in Data Science graduate, and I have a passion for using data to solve complex real-world problems. I have gained experience in the Data Science field through internships using data analytics and machine learning frameworks. Additionally, I have contributed to publications related to data science and am constantly looking for ways to expand my knowledge and skills. I am eager to explore opportunities in the industry to apply my skills and make a positive impact. I believe that data science has the potential to transform industries and create new opportunities, and I am excited to be a part of this change.'},
#  {'skills': ['Python',
#    'Tableau',
#    'R',
#    'SQL',
#    'machine learning',
#    'data warehousing',
#    'cloud computing'],
#   'location': 'Flexible',
#   'role_type': 'Full-Time',
#   'interested_roles': ['Data Scientist', 'Analyst', 'Engineer'],
#   'industries': [],
#   'team_fit': 'I would excel at a team that shares my passion for data and is dedicated to using it to drive positive change.',
#   'summary': 'As a highly motivated individual, I am constantly seeking opportunities to gain real-world experience and expand my skill set. My passion for data science and analytics led me to pursue a career in this field. My experience with Python, Tableau, R, SQL, and other data analysis tools, combined with my expertise in machine learning, data warehousing, and cloud computing, would enable me to thrive in a dynamic environment. I am always eager to learn and explore new technologies, and I believe in using data to drive insights and make informed decisions. With strong analytical thinking and interpersonal skills, I am confident in my ability to collaborate effectively with mentors and professionals to develop new skills that will benefit me in the long term. I am detail-oriented and thrive in a dynamic environment that challenges me to think critically and adapt quickly. My ultimate goal is to grow within a company that values creativity, innovation, and business acumen, and provides opportunities for personal and professional development. I am excited about the prospect of joining a team that shares my passion for data and is dedicated to using it to drive positive change. If you are looking for a highly driven and dedicated Data Scientist/Analyst/Engineer, I would love to connect and explore potential opportunities together.'},
#  {'skills': ['Python',
#    'Java',
#    'R',
#    'JavaScript',
#    'PL/SQL',
#    'Django',
#    'Spring Boot',
#    'Kubernetes',
#    'Apache Spark',
#    'MapReduce',
#    'Hive',
#    'Kafka',
#    'NumPy',
#    'Pandas',
#    'TensorFlow',
#    'Matplotlib',
#    'Scikit-Learn'],
#   'location': '',
#   'role_type': 'Flexible',
#   'interested_roles': ['Software Engineer', 'Data Engineer'],
#   'industries': ['Flexible'],
#   'team_fit': 'This person would excel at a team that values innovation, collaboration, and disciplined software development. They are adept at merging advanced data engineering practices with software development to drive progress.',
#   'summary': 'With 4+ years of experience in both software and data engineering, I have contributed to significant projects in various capacities. My work spans from enhancing data ingestion and automation at Addgene, reducing CI/CD pipeline failures at KPMG, to deploying AI models at Flip Robo Technologies with high accuracy. Notably, at Evolutionary Systems, I took the lead in implementing a scalable HRMS solution on OCI’s Kubernetes Engine and developed EvoGlide—a tool that revolutionized the data migration process. I am committed to merging disciplined software development with advanced data engineering practices to drive progress and innovation. Programming Languages: Python, Java, R, JavaScript, PL/SQL. Frameworks: Django, Spring Boot, Kubernetes, Apache Spark, MapReduce, Hive, Kafka, NumPy, Pandas, TensorFlow, Matplotlib, Scikit-Learn. Tools & Technologies: Node, React, Kubernetes, Git, Jenkins, jQuery, HTML, CSS, XPath, AWS Redshift, Tableau, Jupyter.'},
#  {'skills': ['Data Science',
#    'Machine Learning',
#    'Data Analytics',
#    'Data Visualization',
#    'Natural Language Processing',
#    'Computer Vision',
#    'R',
#    'Python',
#    'SQL',
#    'Tableau',
#    'PowerBI',
#    'Looker'],
#   'location': '',
#   'role_type': 'Flexible',
#   'interested_roles': ['Data Scientist', 'Data Engineer'],
#   'industries': ['Fintech'],
#   'team_fit': 'This person would excel at a team that values collaboration, creativity, and innovation, with a focus on applying data science to drive positive social impact.',
#   'summary': "Having completed my Master's degree in Data Science from Northeastern University, I am an aspiring data scientist with a passion for applying machine learning and data analytics to solve real-world problems. My education has equipped me with a solid foundation in data visualization, natural language processing, computer vision, and other relevant topics, as demonstrated by my projects such as Resume Parser and Job Similarity Scoring and Predicting Depression, Stress, and Anxiety Scores. I also have valuable work experience as a Data Engineer Coop at Wayfair. I developed a self-healing dedupe functionality for their data pipeline in Google BigQuery, which increased the Service Level Objective meetup from 86% to 92%. Additionally, I designed and built ETL procedures, data models, and Looker dashboards for FinTech and Loyalty in the Strategic Programs Team, and supported the data needs of over 100 business stakeholders across various marketing channels. Previously, I worked as a Data Science Intern at Prayaas Corps and Navlakhi Education, where I built databases, implemented predictive models, and developed a recommendation system using SQL, Python, and XGBoost. I am proficient in R, Python, SQL, and data visualization tools such as Tableau, PowerBI, and Looker. I am eager to learn new skills and technologies, and to collaborate with diverse and talented teams. My career goal is to leverage my skills and experience to work on meaningful projects that make a positive impact on society, and to grow as a data science professional and leader."},
#  {'skills': ['Angular',
#    'Spring Boot',
#    'Core Java',
#    'TypeScript',
#    'JavaScript',
#    'Azure',
#    'AWS'],
#   'location': 'Flexible',
#   'role_type': 'Flexible',
#   'interested_roles': ['Software Engineer',
#    'Full Stack Developer',
#    'System Designer',
#    'Database Designer'],
#   'industries': ['Web Development'],
#   'team_fit': 'This person would excel at a team that values collaboration, innovation, and continuous learning. They are self-motivated, detail-oriented, and passionate about staying up-to-date with the latest technologies.',
#   'summary': 'Software Engineer with an experience of 4 years working as a Full Stack developer. Skilled in Angular , Spring Boot, Core Java, TypeScript, and JavaScript and cloud technologies like Azure and AWS. Interested in web development, system design, software design and database design.'},
#  {'skills': ['programming',
#    'full-stack development',
#    'software engineering',
#    'Java',
#    'Python',
#    'JavaScript',
#    'MySQL',
#    'ElasticSearch'],
#   'location': '',
#   'role_type': 'Flexible',
#   'interested_roles': [],
#   'industries': [],
#   'team_fit': 'This person would excel in a team that values innovation, collaboration, and agile development. They are adaptable, proactive, and passionate about technology, making them a great fit for teams that prioritize creative problem-solving and quick iteration.',
#   'summary': "As a Master of Science in Computer Science student from Northeastern University's Khoury College of Computer Sciences, I bring a strong foundation in programming and a passion for developing innovative solutions. With experience in both full-stack development and software engineering, I have honed my skills in languages such as Java, Python, and JavaScript, as well as databases like MySQL and ElasticSearch. Throughout my professional experiences, I have consistently demonstrated my ability to work effectively in an agile environment and collaborate with cross-functional teams to drive positive results. I am eager to leverage my technical skills and passion for technology to make a meaningful impact in a new role, starting from May 2023."},
#  {'skills': ['Data Science', 'Code crafting', 'Pattern unraveling'],
#   'location': 'Flexible',
#   'role_type': 'Flexible',
#   'interested_roles': ['Full-Time'],
#   'industries': [],
#   'team_fit': 'A team that thrives on innovation, creativity and collaboration. A culture that encourages experimentation, learning from failures and celebrating successes.',
#   'summary': "Adventurous soul exploring the intersections of data and innovation. Data Science graduate with a penchant for unraveling patterns and insights. From crafting code to wandering the world, I find beauty in the details and thrive on challenges. Let's connect and share our journeys!"},
#  {'skills': ['Java', 'C++', 'Python', 'Android development'],
#   'location': 'Flexible',
#   'role_type': 'Flexible',
#   'interested_roles': ['Software Engineer'],
#   'industries': ['Flexible'],
#   'team_fit': 'This person would excel at a team that values scalable and secure software development, leveraging cutting-edge technologies to deliver impactful results. They thrive in environments where collaboration, problem-solving, and continuous learning are encouraged.',
#   'summary': 'I am a software engineer with 4+ years of experience in building highly scalable software and Android development experience.I have previous experience as a software engineer at Amazon, Zipcar, and Google Summer of Code, where I built highly scalable and secure systems using cutting-edge technologies such as AWS, Kafka, RxJava, Docker, and Kubernetes. I have demonstrated my ability to deliver impactful results, such as reducing latency by 85%, processing and charging 10,000+ user violations daily, and saving $1+ million annually. I have strong skills in Java, C++, Python, and Android development.'},
#  {'skills': ['Java',
#    'SpringBoot micro-services',
#    'Hibernate',
#    'Angular',
#    'JavaScript'],
#   'location': 'Flexible',
#   'role_type': 'Full-Time',
#   'interested_roles': ['Senior Software Engineer'],
#   'industries': [],
#   'team_fit': 'This person would excel at a team that values strong engineering expertise, is open to learning and growth, and appreciates collaboration. They would thrive in an environment where they can apply their technical skills and experience to drive innovation.',
#   'summary': 'An experienced Senior Software Engineer with a demonstrated history of working in the computer software industry. Skilled in Java, SpringBoot micro-services, Hibernate, Angular, and JavaScript. Strong engineering professional pursuing a graduate degree in Computer Science from Northeastern University.'},
#  {'skills': ['data-driven', 'agile/TDD practices', 'logical reasoning'],
#   'location': 'Flexible',
#   'role_type': 'Flexible',
#   'interested_roles': ['Software Professional', 'Product Development'],
#   'industries': [],
#   'team_fit': 'This person would excel at a team that values innovation, customer-centric approach and is willing to take calculated risks. They thrive in environments where data-driven decisions are made and agile methodologies are practiced.',
#   'summary': 'Customer-centric mindset, data-driven Software Professional with 7+ years of experience in building innovative products, and optimizing their performance. Well-versed with the entire development life cycle and facilitating agile/TDD practices. Strong exposure to the different business functionalities while working in various business-complex use cases. Highly acknowledged for logical reasoning and frequently awarded with the highest performance rating for consistently exceeding expectations and going the extra mile.'},
#  {'skills': ['Machine Learning', 'Deep Learning', 'Computer Vision'],
#   'location': 'Flexible',
#   'role_type': 'Flexible',
#   'interested_roles': ['Machine Learning', 'ML Initiatives'],
#   'industries': ['Healthcare', 'Finance', 'Retail'],
#   'team_fit': '',
#   'summary': "As a machine learning enthusiast with a deep understanding of Machine Learning, Deep Learning, and Computer Vision, I am passionate about using my skills to solve real-world problems. I have experience building and deploying models in a variety of industries, including healthcare, finance, and retail. I am constantly learning and staying up to date with the latest developments in the field. I am looking for opportunities to apply my skills and continue to grow as a professional in the machine learning industry. If you are looking for a dedicated and knowledgeable individual to help take your company's ML initiatives to the next level, please don't hesitate to connect with me."},
#  {'skills': ['Data Science',
#    'Machine Learning Engineering',
#    'Data Engineering',
#    'R',
#    'Python',
#    'SQL'],
#   'location': 'Flexible',
#   'role_type': 'Full-Time',
#   'interested_roles': ['Data Science',
#    'Machine Learning Engineer',
#    'Data Engineer'],
#   'industries': [],
#   'team_fit': 'This person would excel at a team that values data-driven insights, collaboration, and innovation. They thrive in environments where they can apply their analytical skills to drive business growth and contribute to the development of new technologies.',
#   'summary': 'As a recent Data Science graduate from Northeastern University, I am actively seeking opportunities in the fields of Data Science, Machine Learning Engineering, and Data Engineering. My strong mathematical foundation, programming skills, and inclination towards Machine Learning have been honed through practical experiences in data manipulation, analysis, and visualization using R, Python, and SQL. My background includes hands-on experience with cloud services like AWS and Google Cloud. I am passionate about uncovering patterns in data to derive meaningful insights, contributing to the growth and innovation of organizations.'},
#  {'skills': ['Cloud Engineer',
#    'Java programming',
#    'probability and data',
#    'Angular',
#    'AWS',
#    'GCP'],
#   'location': 'Flexible',
#   'role_type': 'Full-Time',
#   'interested_roles': ['Cloud Engineer'],
#   'industries': [],
#   'team_fit': 'This person would excel at a team that values innovation, collaboration, and problem-solving. They thrive in environments where they can share their knowledge and expertise with others.',
#   'summary': 'As a Cloud Engineer, I have a passion for developing and deploying scalable and reliable data solutions using cutting-edge technologies. I am currently pursuing a Master of Science in Computer Science at Northeastern University, where I have also been a Teaching Assistant for CS3200, a course on database design and implementation. I have over 2 years of work experience in various roles, including Cloud Engineer at Deloitte, where I helped design and build cloud-based applications and infrastructure for clients across different industries, and Manager at AIESEC, where I led a team of volunteers to organize and execute social projects and events. I have multiple certifications in software development, Java programming, and probability and data, and I have skills in Angular, AWS, and GCP. I am also the founder of CSKL, a student-run advisory council that connects technology clubs and student societies at KL University, where I graduated with honors in Computer Science. My goal is to leverage my skills and education to create impactful and innovative data solutions that can transform businesses and society.'},
#  {'skills': ['MERN Stack', 'OpenCV', 'UI-UX', 'Backend development'],
#   'location': 'Flexible',
#   'role_type': 'Flexible',
#   'interested_roles': ['Developer', 'Backend developer'],
#   'industries': ['Automotive', 'Government', 'Technology'],
#   'team_fit': 'This person would excel at a team that values learning, innovation, and collaboration. They are adaptable, enthusiastic, and enjoy working on projects that combine technology and problem-solving.',
#   'summary': "I am passionate about learning and applying new technologies to solve real-world problems. I have completed multiple projects and internships in various domains, such as automation, web development, blockchain, and mobile applications, using MERN Stack, OpenCV, etc. Some of my notable experiences include working as a winter intern at Honda Cars India Ltd, where I worked on their website and mobile application's UI-UX and on their workflows, and as a summer intern at NEC Technologies India Pvt Ltd, where I worked with the backend development team for a government project. I graduated from Vellore Institute of Technology with a bachelor's degree in ECE in 2021. Currently pursuing my Master's of Science in Computer Science at Northeastern University, Boston, where my GPA is 4.0/4.0. I am also working as a Teaching Assistant for the course CS 2810 - Mathematics of Data Models under Prof. Almudena Konrad. In addition to my academic pursuits, I am actively engaged in AWS and cloud technologies, currently preparing for the associate developer AWS exam. I look forward to connecting with you and exploring new opportunities."},
#  {'skills': ['Data Analytics',
#    'Algorithms',
#    'Machine Learning',
#    'Artificial Intelligence'],
#   'location': 'Flexible',
#   'role_type': 'Full-Time',
#   'interested_roles': ['AI/ML Engineer',
#    'Data Scientist',
#    'Computer Programmer'],
#   'industries': ['Flexible'],
#   'team_fit': 'This person would excel in a team that values innovation, collaboration and continuous learning. A dynamic team that is open to new ideas and technologies would be a great fit for them.',
#   'summary': "I am currently a junior enrolled in the Northeastern University Honors Program pursuing a Bachelor's of Science in Computer Science along with a minor in Mathematics. I intend on concentrating in artificial intelligence and am passionate about data analytics, algorithms, and machine learning and their applications in various industries."},
#  {'skills': ['Data Science',
#    'Advanced Machine Learning',
#    'Statistics',
#    'Python',
#    'R',
#    'PyTorch',
#    'Power BI',
#    'Azure Services'],
#   'location': 'Flexible',
#   'role_type': 'Flexible',
#   'interested_roles': ['Data Scientist'],
#   'industries': [],
#   'team_fit': 'This person would excel at a team that values innovation, collaboration, and problem-solving. They thrive in environments where they can leverage their technical skills to drive business impact.',
#   'summary': "I love solving problems. With a Master's in Artificial Intelligence from Northeastern University and a background in engineering, I have a strong foundation in data science, advanced machine learning, and statistics. As a Data Scientist at Pontoon Solutions, I modernized and improved the Supplier Recommendation Engine. This engine aggregates high-dimensional structured data and resolves the complex business problem of redundancy in vendor management. It helps clients condense their supplier base by 66%% for optimal and manageable performance. I leveraged agile methods to develop applications based on best coding practices and integrate Azure services. I also have experience as a Graduate Teaching Assistant at Khoury College of Computer Sciences. I led the Teaching Assistance Staff in orchestrating course content, schedule, assignment grading, and support for 120+ students pursuing the Introduction to Data Mining and Machine Learning course. I have leveraged my skills in Natural Language Processing to automate internal workflows such as semantic document filtering, reducing research hours for Patent Analysts by 24 hours. I'm a relentless learner, thriving on hands-on challenges and guided mentorship. My toolkit includes Python, R, PyTorch, Power BI, and Azure Services, and I'm always expanding my horizons. My passion lies in uncovering hidden insights within growing data stores and using those to build impactful machine-learning models that transform businesses. If you're seeking an AI enthusiast driven to crack open new possibilities and unlock your data's potential, let's connect!"},
#  {'skills': ['Python',
#    'SQL',
#    'PyTorch',
#    'Pandas',
#    'Numpy',
#    'Plotly',
#    'statistical analysis',
#    'data visualization'],
#   'location': 'Flexible',
#   'role_type': 'Flexible',
#   'interested_roles': ['Data Scientist', 'Researcher', 'Analyst'],
#   'industries': ['Healthcare', 'Technology'],
#   'team_fit': 'This person would excel at a team that values collaboration, innovation, and data-driven decision making. They thrive in an environment where they can apply cutting-edge NLP and ML techniques to solve real-world challenges and drive impactful outcomes.',
#   'summary': "I am an AI Master's student with a strong focus on Natural Language Processing (NLP) and Machine Learning (ML). I have completed several projects and internships related to these domains, such as the Data Science Internship at LG Vertech, where I conducted predictive analysis to detect weak batteries and optimize operational efficiency. I am proficient in Python, SQL, and ML frameworks such as PyTorch, and I have a solid foundation in statistical analysis and data visualization. As a Graduate Student Researcher at Northeastern University, I work with mHealth research lab to perform data analysis and visualization on large-scale accelerometer data from the NHANES survey. Using Python libraries such as Pandas, Numpy, and Plotly, I manipulate and understand the data distribution, and identify outliers and anomalies. This experience has enhanced my skills in unstructured data, exploratory data analysis, and data wrangling. I am passionate about applying cutting-edge NLP and ML techniques to solve real-world challenges and drive impactful outcomes. Let's collaborate and unleash the power of data!"}]

# %%
with open('../data/extracted_summaries.json', 'w') as f:
    json.dump(json_outputs, f)

# %% [markdown]
# ## Roles

# %%
match_data = pd.read_json('../data/jobs.json')
match_data
# Out:
#            job_id                 company_name  \
# 0         1218575          Children's Nebraska
# 1        95428182     CLEVELAND KIDS BOOK BANK
# 2       280496925  Washington State University
# 3       368586246                STL Fertility
# 4       805229245                          nan
# ...           ...                          ...
# 87173  3906266212               Synectics Inc.
# 87174  3906266217                     The Dyrt
# 87175  3906266248                       GoodRx
# 87176  3906267126                    Pinterest
# 87177  3906267131                 EPS Learning
#
#                                                    title  \
# 0                                  Respiratory Therapist
# 1                             Administrative Coordinator
# 2      Coordinator for Multicultural Student Organiza...
# 3                                           Embryologist
# 4                               Manager, Retail Pharmacy
# ...                                                  ...
# 87173                               Phlebotomist - Float
# 87174                      Senior Frontend/App Developer
# 87175                    Account Manager, Client Success
# 87176       Staff Software Engineer, ML Serving Platform
# 87177               Account Executive, Oregon/Washington
#
#                                              description            location  \
# 0      At Children’s, the region’s only full-service ...           Omaha, NE
# 1      Job Title: Administrative CoordinatorOrganizat...       Cleveland, OH
# 2      The Coordinator serves as the principal adviso...         Pullman, WA
# 3      Job duties:To recover oocytes from follicular ...        St Louis, MO
# 4      SUMMARY:Manages operation and supervises all d...          Tucson, AZ
# ...                                                  ...                 ...
# 87173  Job Description\n\nThe Patient Services Repres...  Carroll County, MD
# 87174  The Dyrt is the largest digital camping platfo...       United States
# 87175  GoodRx is America’s healthcare marketplace. Ea...       United States
# 87176  About Pinterest:\n\nMillions of people across ...       United States
# 87177  Company Overview\n\nEPS Learning is a leading ...         Spokane, WA
#
#             type  remote                               skills  \
# 0      Full-time   False                 Health Care Provider
# 1      Full-time   False                       Administrative
# 2      Full-time   False                  Education, Training
# 3      Full-time   False                 Health Care Provider
# 4      Full-time   False          Business Development, Sales
# ...          ...     ...                                  ...
# 87173   Contract   False                              Science
# 87174  Full-time    True  Engineering, Information Technology
# 87175  Full-time    True          Business Development, Sales
# 87176  Full-time    True  Engineering, Information Technology
# 87177  Full-time    True          Business Development, Sales
#
#                                                 industry  \
# 0                              Hospitals and Health Care
# 1                               Non-profit Organizations
# 2                                       Higher Education
# 3
# 4                              Hospitals and Health Care
# ...                                                  ...
# 87173                            Staffing and Recruiting
# 87174               Technology, Information and Internet
# 87175                          Hospitals and Health Care
# 87176  IT Services and IT Consulting, Software Develo...
# 87177                  Education Administration Programs
#
#                                          application_url
# 0                              www.childrensnebraska.org
# 1               https://www.kidsbookbank.org/employment/
# 2      https://wsu.wd5.myworkdayjobs.com/en-US/WSU_Jo...
# 3      https://www.indeed.com/job/embryologist-944f8c...
# 4      https://jobs.tmcaz.com/manager-pharmacy-retail...
# ...                                                  ...
# 87173  https://www.synectics.com/candidate-apply.php/...
# 87174  https://the-dyrt.breezy.hr/p/31c6745b3473-seni...
# 87175  https://goodrx.wd1.myworkdayjobs.com/Careers/j...
# 87176  https://www.pinterestcareers.com/en/jobs/58824...
# 87177  https://epsoperations.bamboohr.com/careers/122...
#
# [87178 rows x 10 columns]

# %%
industries = list(set(map(lambda x: x.strip(), (','.join(match_data['industry'].tolist())).split(','))))
industries.remove('')

with open('../data/industries.pkl', 'wb') as f:
    pickle.dump(industries, f)

# %%
roles = map(lambda x: x.strip(), (','.join(match_data['title'].tolist())).split(','))
popular_roles = list(map(lambda x: x[0], Counter(roles).most_common(10000)))
popular_roles[:5]
# Out:
# ['Manager',
#  'Director',
#  'Customer Service Representative',
#  'Senior Manager',
#  'Retail Sales Associate']

# %%
roles_filtered = []

for role in popular_roles:
    is_valid = f''' 
    Is this a professional role title: "{role}".
    Answer in "Yes" or "No".  Do not explain. Bias against false positives.
    '''
    output = ollama.generate(model = "llama3", prompt = is_valid)
    if output['response'] == 'Yes' and len(role) > 3:
        refined_title = ' '.join([x for x in role.split(' ') if x not in ('Senior', 'Junior', 'Staff', 'I', 'II', 'III')])
        roles_filtered.append(refined_title)

roles_refined = []

for role in roles_filtered:

    make_generic = f''' 
    Someone listed this role on a job board: {role}.
    This role title may contain additional details about the company, the place, or seniority.
    What would be a more generic role title, skipping all the details? Just provide answer, do not explain.
    '''
    output = ollama.generate(model = "llama3", prompt = make_generic)
    roles_refined.append(output['response'])

roles_refined = list(set(roles_refined))
len(roles_refined)

# %%
with open('../data/roles.pkl', 'wb') as f:
    pickle.dump(roles_refined, f)
