# %%
import pandas as pd
import numpy as np

# %%
companies = pd.read_csv('../data/companies/companies.csv')
industries = pd.read_csv('../data/companies/company_industries.csv')
specialities = pd.read_csv('../data/companies/company_specialities.csv').groupby('company_id').agg({'speciality': lambda x: ', '.join(x)})
employee_counts = pd.read_csv('../data/companies/employee_counts.csv').groupby('company_id').agg(lambda x: int(x.mean()))
company_details = companies.merge(industries, on='company_id')\
                           .merge(specialities, on='company_id')\
                           .merge(employee_counts, on='company_id')\
                           .drop(['address', 'url', 'time_recorded', 'company_size', 'follower_count'], axis=1)
company_details = company_details[company_details['country'] == 'US'][company_details['employee_count'] > 0].sort_values('employee_count', ascending=False)

conditions = [(company_details['employee_count'] <= 100),
              (company_details['employee_count'] > 100) & (company_details['employee_count'] <= 1000),
              (company_details['employee_count'] > 1000) & (company_details['employee_count'] <= 10000),
              (company_details['employee_count'] > 10000)]

sizes = ['early stage startup', 'small', 'medium', 'large']

company_details['size'] = np.select(conditions, sizes)
company_details
# Out:
# /var/folders/v8/l597fdmn691ctljk27sgct540000gn/T/ipykernel_71351/2421040050.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   company_details = company_details[company_details['country'] == 'US'][company_details['employee_count'] > 0].sort_values('employee_count', ascending=False)
#        company_id                           name  \
# 89           1586                         Amazon
# 252          2646                        Walmart
# 258          2677                     McDonald's
# 109          1680                      Cognizant
# 0            1009                            IBM
# ...           ...                            ...
# 11910     5219754                      Q-SAQ INC
# 16187    69158025              David Company LLC
# 17577    98803167    Blue Horizons Financial LLC
# 14353    18008857  International Drivers Academy
# 17786   103414908                  Somnio Wealth
#
#                                              description        state country  \
# 89     Amazon is guided by four principles: customer ...           WA      US
# 252    Sixty years ago, Sam Walton started a single m...     Arkansas      US
# 258    McDonald’s is the world’s leading global foods...     Illinois      US
# 109    Cognizant (Nasdaq-100: CTSH) engineers modern ...   New Jersey      US
# 0      At IBM, we do more than work. We create. We cr...           NY      US
# ...                                                  ...          ...     ...
# 11910  Q-SAQ, INC is a financially sound US organizat...      Florida      US
# 16187  David company is a true full-service design an...   Washington      US
# 17577  Our mission at Blue Horizons Financial is to c...            0      US
# 14353  The International Drivers Academy is a driving...  Washington       US
# 17786  Somnio Wealth is a Wealth Management Firm in L...     Kentucky      US
#
#                    city zip_code                            industry  \
# 89              Seattle    98109                Software Development
# 252         Bentonville    72712                              Retail
# 258             Chicago    60607                         Restaurants
# 109             Teaneck    07666       IT Services and IT Consulting
# 0      Armonk, New York    10504       IT Services and IT Consulting
# ...                 ...      ...                                 ...
# 11910         MELBOURNE    32940        Wholesale Building Materials
# 16187         Arlington    98223           Architecture and Planning
# 17577          Portland        0                  Financial Services
# 14353          Bellevue    98004  Professional Training and Coaching
# 17786        Louisville    40222                  Financial Services
#
#                                               speciality  employee_count  \
# 89              e-Commerce, Retail, Operations, Internet          748029
# 252    Technology, Transportation, Logistics, Merchan...          429878
# 258    Restaurant, sustainability, foodservice, franc...          355436
# 109    Interactive, Intelligent Process Automation, D...          314529
# 0      Cloud, Mobile, Cognitive, Security, Research, ...          312903
# ...                                                  ...             ...
# 11910  Vehicle Barriers, Vehicle Detection, Vehicle C...               1
# 16187  Architecture, construction, leasing, commercia...               1
# 17577  Retirement Strategies, Child Headstart Plans, ...               1
# 14353  State Certified, Driver Training, Defensive Dr...               1
# 17786  financial planning, wealth management, financi...               1
#
#                       size
# 89                   large
# 252                  large
# 258                  large
# 109                  large
# 0                    large
# ...                    ...
# 11910  early stage startup
# 16187  early stage startup
# 17577  early stage startup
# 14353  early stage startup
# 17786  early stage startup
#
# [15864 rows x 11 columns]

# %%
benefits = pd.read_csv('../data/jobs/benefits.csv')
job_industries = pd.read_csv('../data/jobs/job_industries.csv')
job_skills = pd.read_csv('../data/jobs/job_skills.csv')
salaries = pd.read_csv('../data/jobs/salaries.csv')
industries = pd.read_csv('../data/mappings/industries.csv')
skills = pd.read_csv('../data/mappings/skills.csv')

job_details = benefits.merge(job_industries, on='job_id', how='outer')\
                      .merge(job_skills, on='job_id', how='outer')\
                      .merge(skills, on='skill_abr', how='outer')\
                      .merge(industries, on='industry_id', how='outer')\
                      .drop(['skill_abr', 'industry_id', 'inferred'], axis=1)\
                      .astype(str)\
                      .groupby('job_id').agg(lambda x: ', '.join(set(x)))\
                      .merge(salaries.astype(str), on='job_id', how='outer')\
                      .drop(['compensation_type', 'currency', 'salary_id'], axis=1)\
                      .rename({'type': 'benefits',
                               'skill_name':'skills',
                               'industry_name':'industry'}, axis=1)
job_details
# Out:
#             job_id                                           benefits  \
# 0       1014822088                                             401(k)
# 1        103254301                                                nan
# 2        103860943                                                nan
# 3       1093227543                                                nan
# 4         10998357                                                nan
# ...            ...                                                ...
# 128422      921716                                                nan
# 128423   935210241                                                nan
# 128424    95428182  Dental insurance, Medical insurance, Disabilit...
# 128425     9615617                                                nan
# 128426   974774701                                                nan
#
#                                               skills  \
# 0                                   Sales, Marketing
# 1       Art/Creative, Information Technology, Design
# 2                                                nan
# 3               Sales, Product Management, Marketing
# 4                          Management, Manufacturing
# ...                                              ...
# 128422                              Sales, Marketing
# 128423                                         Legal
# 128424                                Administrative
# 128425                                           nan
# 128426                              Sales, Marketing
#
#                           industry max_salary med_salary min_salary pay_period
# 0             Software Development    80000.0        nan    70000.0     YEARLY
# 1                  Design Services   300000.0        nan    60000.0     YEARLY
# 2             Truck Transportation       19.0        nan       18.0     HOURLY
# 3       Food and Beverage Services   120000.0        nan    60000.0     YEARLY
# 4                      Restaurants    65000.0        nan    45000.0     YEARLY
# ...                            ...        ...        ...        ...        ...
# 128422                 Real Estate       20.0        nan       17.0     HOURLY
# 128423                Law Practice        NaN        NaN        NaN        NaN
# 128424    Non-profit Organizations        nan       25.0        nan     HOURLY
# 128425      Beverage Manufacturing        NaN        NaN        NaN        NaN
# 128426                         nan        NaN        NaN        NaN        NaN
#
# [128427 rows x 8 columns]

# %%
postings = pd.read_csv('../data/postings.csv')[['job_id', 
                                             'company_id',
                                            'company_name',
                                            'title', 
                                            'description', 
                                            'location',
                                            'formatted_work_type',
                                            'remote_allowed',
                                            'skills_desc',
                                            'application_url']]
print(f'Postins data available for {len(set(postings["job_id"]))} jobs.')
postings_data = postings.astype(str)\
                        .merge(job_details, on='job_id')

postings_data['remote_allowed'] = postings_data['remote_allowed'].map({'nan': False, '1.0': True})
postings_data['skills_desc'] = postings_data['skills_desc'].astype(str).replace('nan', '')
postings_data['industry'] = postings_data['industry'].astype(str).replace('nan', '')
postings_data['description'] = postings_data['description'] + postings_data['skills_desc']
postings_data.drop(['skills_desc'], axis=1, inplace=True)

postings_data = postings_data[postings_data['application_url'] != "nan"]
print(f'Distinct Application_url available for {len(set(postings["application_url"]))} jobs.')
postings_data
# Out:
# Postins data available for 123849 jobs.
# Distinct Application_url available for 84801 jobs.
#             job_id  company_id                 company_name  \
# 8          1218575    721189.0          Children's Nebraska
# 16        95428182  55624331.0     CLEVELAND KIDS BOOK BANK
# 37       280496925    166875.0  Washington State University
# 40       368586246  81247311.0                STL Fertility
# 46       805229245         nan                          nan
# ...            ...         ...                          ...
# 123706  3906266212    413796.0               Synectics Inc.
# 123707  3906266217   6404239.0                     The Dyrt
# 123708  3906266248   2466850.0                       GoodRx
# 123711  3906267126   1124131.0                    Pinterest
# 123712  3906267131  90552133.0                 EPS Learning
#
#                                                     title  \
# 8                                   Respiratory Therapist
# 16                             Administrative Coordinator
# 37      Coordinator for Multicultural Student Organiza...
# 40                                           Embryologist
# 46                               Manager, Retail Pharmacy
# ...                                                   ...
# 123706                               Phlebotomist - Float
# 123707                      Senior Frontend/App Developer
# 123708                    Account Manager, Client Success
# 123711       Staff Software Engineer, ML Serving Platform
# 123712               Account Executive, Oregon/Washington
#
#                                               description            location  \
# 8       At Children’s, the region’s only full-service ...           Omaha, NE
# 16      Job Title: Administrative CoordinatorOrganizat...       Cleveland, OH
# 37      The Coordinator serves as the principal adviso...         Pullman, WA
# 40      Job duties:To recover oocytes from follicular ...        St Louis, MO
# 46      SUMMARY:Manages operation and supervises all d...          Tucson, AZ
# ...                                                   ...                 ...
# 123706  Job Description\n\nThe Patient Services Repres...  Carroll County, MD
# 123707  The Dyrt is the largest digital camping platfo...       United States
# 123708  GoodRx is America’s healthcare marketplace. Ea...       United States
# 123711  About Pinterest:\n\nMillions of people across ...       United States
# 123712  Company Overview\n\nEPS Learning is a leading ...         Spokane, WA
#
#        formatted_work_type  remote_allowed  \
# 8                Full-time           False
# 16               Full-time           False
# 37               Full-time           False
# 40               Full-time           False
# 46               Full-time           False
# ...                    ...             ...
# 123706            Contract           False
# 123707           Full-time            True
# 123708           Full-time            True
# 123711           Full-time            True
# 123712           Full-time            True
#
#                                           application_url  \
# 8                               www.childrensnebraska.org
# 16               https://www.kidsbookbank.org/employment/
# 37      https://wsu.wd5.myworkdayjobs.com/en-US/WSU_Jo...
# 40      https://www.indeed.com/job/embryologist-944f8c...
# 46      https://jobs.tmcaz.com/manager-pharmacy-retail...
# ...                                                   ...
# 123706  https://www.synectics.com/candidate-apply.php/...
# 123707  https://the-dyrt.breezy.hr/p/31c6745b3473-seni...
# 123708  https://goodrx.wd1.myworkdayjobs.com/Careers/j...
# 123711  https://www.pinterestcareers.com/en/jobs/58824...
# 123712  https://epsoperations.bamboohr.com/careers/122...
#
#                                                  benefits  \
# 8                                                     nan
# 16      Dental insurance, Medical insurance, Disabilit...
# 37                                                    nan
# 40                               Vision insurance, 401(k)
# 46                                                    nan
# ...                                                   ...
# 123706         Dental insurance, Vision insurance, 401(k)
# 123707                                                nan
# 123708        Vision insurance, Medical insurance, 401(k)
# 123711                                                nan
# 123712                                                nan
#
#                                      skills  \
# 8                      Health Care Provider
# 16                           Administrative
# 37                      Training, Education
# 40                     Health Care Provider
# 46              Sales, Business Development
# ...                                     ...
# 123706                              Science
# 123707  Engineering, Information Technology
# 123708          Sales, Business Development
# 123711  Engineering, Information Technology
# 123712          Sales, Business Development
#
#                                                  industry max_salary  \
# 8                               Hospitals and Health Care        NaN
# 16                               Non-profit Organizations        nan
# 37                                       Higher Education     4817.0
# 40                                                               NaN
# 46                              Hospitals and Health Care   165000.0
# ...                                                   ...        ...
# 123706                            Staffing and Recruiting        NaN
# 123707               Technology, Information and Internet        NaN
# 123708                          Hospitals and Health Care        NaN
# 123711  Technology, Information and Internet, Software...        NaN
# 123712                  Education Administration Programs        NaN
#
#        med_salary min_salary pay_period
# 8             NaN        NaN        NaN
# 16           25.0        nan     HOURLY
# 37            nan     4061.0    MONTHLY
# 40            NaN        NaN        NaN
# 46            nan   110000.0     YEARLY
# ...           ...        ...        ...
# 123706        NaN        NaN        NaN
# 123707        NaN        NaN        NaN
# 123708        NaN        NaN        NaN
# 123711        NaN        NaN        NaN
# 123712        NaN        NaN        NaN
#
# [87178 rows x 16 columns]

# %%
match_data = postings_data[['job_id',
                            'company_name',
                            'title',
                            'description',
                            'location',
                            'formatted_work_type',
                            'remote_allowed',
                            'skills',
                            'industry',
                            'application_url']].rename({'formatted_work_type': 'type', 'remote_allowed': 'remote'}, axis=1)
match_data
# Out:
#             job_id                 company_name  \
# 8          1218575          Children's Nebraska
# 16        95428182     CLEVELAND KIDS BOOK BANK
# 37       280496925  Washington State University
# 40       368586246                STL Fertility
# 46       805229245                          nan
# ...            ...                          ...
# 123706  3906266212               Synectics Inc.
# 123707  3906266217                     The Dyrt
# 123708  3906266248                       GoodRx
# 123711  3906267126                    Pinterest
# 123712  3906267131                 EPS Learning
#
#                                                     title  \
# 8                                   Respiratory Therapist
# 16                             Administrative Coordinator
# 37      Coordinator for Multicultural Student Organiza...
# 40                                           Embryologist
# 46                               Manager, Retail Pharmacy
# ...                                                   ...
# 123706                               Phlebotomist - Float
# 123707                      Senior Frontend/App Developer
# 123708                    Account Manager, Client Success
# 123711       Staff Software Engineer, ML Serving Platform
# 123712               Account Executive, Oregon/Washington
#
#                                               description            location  \
# 8       At Children’s, the region’s only full-service ...           Omaha, NE
# 16      Job Title: Administrative CoordinatorOrganizat...       Cleveland, OH
# 37      The Coordinator serves as the principal adviso...         Pullman, WA
# 40      Job duties:To recover oocytes from follicular ...        St Louis, MO
# 46      SUMMARY:Manages operation and supervises all d...          Tucson, AZ
# ...                                                   ...                 ...
# 123706  Job Description\n\nThe Patient Services Repres...  Carroll County, MD
# 123707  The Dyrt is the largest digital camping platfo...       United States
# 123708  GoodRx is America’s healthcare marketplace. Ea...       United States
# 123711  About Pinterest:\n\nMillions of people across ...       United States
# 123712  Company Overview\n\nEPS Learning is a leading ...         Spokane, WA
#
#              type  remote                               skills  \
# 8       Full-time   False                 Health Care Provider
# 16      Full-time   False                       Administrative
# 37      Full-time   False                  Training, Education
# 40      Full-time   False                 Health Care Provider
# 46      Full-time   False          Sales, Business Development
# ...           ...     ...                                  ...
# 123706   Contract   False                              Science
# 123707  Full-time    True  Engineering, Information Technology
# 123708  Full-time    True          Sales, Business Development
# 123711  Full-time    True  Engineering, Information Technology
# 123712  Full-time    True          Sales, Business Development
#
#                                                  industry  \
# 8                               Hospitals and Health Care
# 16                               Non-profit Organizations
# 37                                       Higher Education
# 40
# 46                              Hospitals and Health Care
# ...                                                   ...
# 123706                            Staffing and Recruiting
# 123707               Technology, Information and Internet
# 123708                          Hospitals and Health Care
# 123711  Technology, Information and Internet, Software...
# 123712                  Education Administration Programs
#
#                                           application_url
# 8                               www.childrensnebraska.org
# 16               https://www.kidsbookbank.org/employment/
# 37      https://wsu.wd5.myworkdayjobs.com/en-US/WSU_Jo...
# 40      https://www.indeed.com/job/embryologist-944f8c...
# 46      https://jobs.tmcaz.com/manager-pharmacy-retail...
# ...                                                   ...
# 123706  https://www.synectics.com/candidate-apply.php/...
# 123707  https://the-dyrt.breezy.hr/p/31c6745b3473-seni...
# 123708  https://goodrx.wd1.myworkdayjobs.com/Careers/j...
# 123711  https://www.pinterestcareers.com/en/jobs/58824...
# 123712  https://epsoperations.bamboohr.com/careers/122...
#
# [87178 rows x 10 columns]

# %%
import ollama
import pickle

states_detected = []

for location in match_data.location:
    prompt = f'''
    This is a location in the US: {location}. Return the full name of the State it is located in. If no particular state is found, return an empty string. Do not explain, just return the name of the state.
    '''
    states_detected.append(ollama.generate(model = "llama3", prompt = prompt)['response'])

match_data['location'] = states_detected

with open('../data/states.pkl', 'rb') as file:
    states = pickle.load(file)

match_data.loc[~match_data['location'].isin(states), 'location'] = ''

match_data.to_json('../data/jobs.json', orient='records')
